# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO
import numpy as np

iter = 1000
dice1 = np.random.randint(1,6,size=iter)
dice2 = np.random.randint(1,6,size=iter)

sum = dice1+dice2
track_seven = []
track_even = []
for i in sum:
    if i > 7:
        track_seven.append(i)
    if i % 2 != 0:
        track_even.append(i)

print(f"The probability of a number being greater than 7 after {iter} iterations is: {round((len(track_seven)/iter)*100,4)}%")
print(f"The probability of a number being even after {iter} iterations is: {round((len(track_even)/iter)*100,4)}%")
# Out:
# The probability of a number being greater than 7 after 1000 iterations is: 23.0%
# The probability of a number being even after 1000 iterations is: 47.6%

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

#print(ball_box)

# TODO


def shuffle(box):
    balls = []
    for i in range(5):
        out = np.random.randint(60)
        if out not in balls:
            balls.append(box[out])
    return balls


not_same_color = 0

for i in range (iter):
    checker = True
    balls = shuffle(ball_box)
    for j in range(1,4):
        if balls[j] != balls[0]:
            checker = False
            not_same_color +=1
            break
    
print(f"After {iter} iterations, there is a {((iter-not_same_color)/iter)*100}% chance that all 5 balls are the same color")
# Out:
# After 1000 iterations, there is a 8.4% chance that all 5 balls are the same color
